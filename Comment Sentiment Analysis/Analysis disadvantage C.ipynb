# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 
import matplotlib.pyplot as plt
import jieba.analyse
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import feature_extraction
import jieba.posseg as pseg
from __future__ import print_function
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.cluster import KMeans, MiniBatchKMeans

# %%
dfc = pd.read_csv('..\data\data_C.csv',index_col = 0,dtype = {'simple review':str,'review':str,})

# %%
sum(pd.notnull(dfc['review'])) # 3062 lines with review
dfc_review = dfc[pd.notnull(dfc['review'])] 
dfc_review = dfc_review.reset_index(drop = True)
dfc_review
# Out:
# 3062
#                                car type  purch time  \
# 0                  2019款奔驰C级C 300 L 运动版  2019-01-01
# 1                  2019款奔驰C级C 300 L 运动版  2019-01-01
# 2                      2018款奔驰C级C 200 L  2018-11-01
# 3            2018款奔驰C级C 200 L 运动型 成就特别版  2018-07-01
# 4                  2018款奔驰C级C 200 L 运动版  2018-01-01
# 5                   2008款奔驰C级C 200K 时尚型  2008-05-01
# 6               2019款奔驰C级C 180 L 时尚型运动版  2018-10-01
# 7                    2017款奔驰C级C 200 运动版  2017-11-19
# 8                      2015款奔驰C级C 300 L  2016-05-25
# 9                   2010款奔驰C级C 180K 经典版  2011-12-06
# 10          2020款奔驰C级C 260 L 4MATIC 运动版  2020-01-01
# 11                   2020款奔驰C级C 300 运动版  2020-01-01
# 12                   2020款奔驰C级C 300 运动版  2020-01-01
# 13                   2020款奔驰C级C 300 运动版  2020-01-01
# 14           2020款奔驰C级改款 C 200 L 动感型运动版  2020-01-01
# 15           2020款奔驰C级改款 C 200 L 动感型运动版  2020-02-01
# 16           2020款奔驰C级改款 C 200 L 动感型运动版  2020-01-01
# ...

# %%
lst = []
for i in range(0,len(dfc_review)):
    if '[不满意]' in dfc_review.review[i]:
        lst.append(i)
neg_review = []
for i in dfc_review.loc[lst,'review'].tolist():
    review = i.split('\n')
    index = review.index('[不满意]')
    neg_review.append(review[index+1])

# %%
dfc_neg_review1 = dfc_review.loc[lst,]
dfc_neg_review1['neg_review'] = neg_review

# %%
lst2 = []
for i in range(0,len(dfc_review)):
    if '缺点：' in dfc_review.review[i]:
        lst2.append(i)
lst2 = lst2[1:]    #delete 552.have both '[最满意]' and'缺点：'
neg_review = []
for i in dfc_review.loc[lst2,'review'].tolist():
    review = i.split('\n')
    index = review.index('缺点：')
    neg_review.append(review[index+1])

# %%
dfc_neg_review2 = dfc_review.loc[lst2,]
dfc_neg_review2['neg_review'] = neg_review
dfc_neg_review = pd.concat([dfc_neg_review1, dfc_neg_review2])

# %%
len(dfc_neg_review)
# Out:
# 2934

# %%
dfc_neg_review.to_csv('..\data\data_C_negative_review.csv')

# %%
dfc_just_neg_review = pd.DataFrame(dfc_neg_review.loc[:,'neg_review'])
dfc_just_neg_review = dfc_just_neg_review.reset_index(drop = True)
dfc_just_neg_review.to_csv('..\data\data_C_just_negative_review.csv')

# %%
(dfc_neg_review.neg_review).nunique()
# Out:
# 1643

# %%
#!--encoding=utf-8
def loadDataset():
    corpus = []
    #加载停用词表
    stop = [line.strip().decode('utf-8') for line in open('..\data\stop_words_3.txt','rb').readlines() ]
    with open('..\data\data_C_just_negative_review.csv', 'r', encoding='utf-8') as f:
        for line in f:
            segs = jieba.lcut(line.strip(), cut_all=True)   #, cut_all=True
            segs = pseg.cut(line)
            final = ''
            for seg, flag in segs:
                #去停用词
                if seg not in stop:
                   #去数词和去字符串
                   if flag !='m' and flag !='x':
                    #输出分词
                        final +=' '+ seg 
            corpus.append(final)  
            
    return corpus

def transform(corpus,n_features=1000):
    vectorizer = TfidfVectorizer(max_df=0.5, max_features=n_features, min_df=2,use_idf=True)
    X = vectorizer.fit_transform(corpus)
    return X,vectorizer

def train(X,vectorizer,true_k=10,minibatch = False,showLable = False):
    #使用采样数据还是原始数据训练k-means，    
    if minibatch:
        km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', n_init=1,
                             init_size=1000, batch_size=1000, verbose=False)
    else:
        km = KMeans(n_clusters=true_k, init='k-means++', max_iter=300, n_init=1,
                    verbose=False)
    km.fit(X)    
    if showLable:
        print("Top terms per cluster:")
        order_centroids = km.cluster_centers_.argsort()[:, ::-1]
        terms = vectorizer.get_feature_names()
        print (vectorizer.get_stop_words())
        for i in range(true_k):
            print("Cluster %d:" % i, end='')
            for ind in order_centroids[i, :10]:
                print(' %s' % terms[ind], end='')
            print()
    result = list(km.predict(X))
    print ('Cluster distribution:')
    print (dict([(i, result.count(i)) for i in result]))
    return -km.score(X)

# %%
def test():
    '''测试选择最优参数'''
    dataset = loadDataset()    
    print("%d documents" % len(dataset))
    X,vectorizer = transform(dataset,n_features=500)
    true_ks = []
    scores = []
    for i in xrange(3,80,1):        
        score = train(X,vectorizer,true_k=i)/len(dataset)
        print (i,score)
        true_ks.append(i)
        scores.append(score)
    plt.figure(figsize=(8,4))
    plt.plot(true_ks,scores,label="error",color="red",linewidth=1)
    plt.xlabel("n_features")
    plt.ylabel("error")
    plt.legend()
    plt.show()

# %%
def out():
    dataset = loadDataset()
    X,vectorizer = transform(dataset,n_features=500)
    score = train(X,vectorizer,true_k=10,showLable=True)/len(dataset)
    print (score)
#test()

# %%
out()
# Out:
# Top terms per cluster:
# None
# Cluster 0: 倒车 雷达 影像 导航 奔驰 宝马 配置 空间 好看 后排
# Cluster 1: 油耗 个油 市区 平均 起步 平时 接受 空间 目前 动力
# Cluster 2: 空间 后排 储物 很小 太小 家庭 适合 适用 个人 售后
# Cluster 3: 味道 新车 太阳 品牌 提车 车里 车门 买车 奔驰 气味
# Cluster 4: 够用 角度 家用 考虑 后备箱 后排 麻烦 处理 大家 外面
# Cluster 5: 顿挫 换挡 明显 变速箱 异响 加速 刹车 低速 动力 换档
# Cluster 6: 异响 声音 发动机 刹车 满意 问题 后排 座椅 起步 奔驰
# Cluster 7: 太值 普通车 同学 奔驰车 售价 值得 重要 有个 方面 喜欢
# Cluster 8: 后视镜 折叠 电动 自动 居然 有些 进入 钥匙 倒车 落地
# Cluster 9: 保养 维修 配件 价格 奔驰 费用 售后 成本 一般 后期
# Cluster distribution:
# {6: 1738, 4: 34, 7: 41, 5: 224, 3: 103, 9: 141, 1: 141, 2: 258, 0: 194, 8: 61}
# 0.83789225001151

# %%
dataset = loadDataset()[1:]

# %%
comment = [['倒车','雷达'],['油耗','市区'],['空间','储物'],['味道','新车'],['角度','后备箱'],['换挡','变速箱'],
           ['异响','声音'],['售价','普通车'],['后视镜','折叠'],['保养','维修']]
for j in comment:    
    for i in range(len(dataset)):
        if j[0] in dataset[i] and j[1] in dataset[i] :
            print(j,':')
            print(dfc_just_neg_review.loc[i,:].neg_review)
            break
# Out:
# ['倒车', '雷达'] :
# 很多城市的落地价比我们便宜好几W，这个太坑了！后排中间凸起太多了。倒车雷达反应迟钝，倒车都碰到一次树了。防爆胎好像比较硬。方向盘比较重。
# ['油耗', '市区'] :
# 40码一下行驶油门略沉，降档挫顿感明显。油耗相对1.6的车型还是有点高的。平常开c驾驶模式不深踩油门还是1700公里10.4油耗，一半高速一半市区吧。对比我之前的新款思域，这个动力还是挺失望的
# ['空间', '储物'] :
# 储物空间少，地盘太低了，中控屏容易刮花，200大洋买了个中控壳贴上了，美滋滋，发动机声音大，另外就是竟然没有锁车自动关窗，我每次锁车后忘了关窗户的时候都要再去车里关窗户，还不如我姐的低配凌渡呢，不是标配全液晶，花了4900选装全液晶仪表盘
# ['味道', '新车'] :
# 新车有比较大的味道，操控很一般，减震比较差！
# ['角度', '后备箱'] :
# 后备箱有点小了，我自己的话是够用了，但是从家用的角度去考虑的话真的是不太够用。
# ['换挡', '变速箱'] :
# 最不满意就是变速箱换挡问题，今天提车第5天，前两天就一直有，因为新物件还没来得急熟练，今天仔细发现车子起步1档升2档有时顺畅有时需要需要2500到3000转才能换挡，还为是哪里没操作好，后来仔细体验了下，我觉得是存在问题的，转速上来了根本换不上档，正常车辆哪里会这样！这对于一个9档变速箱来说我觉得是不应该出现的问题！发动机咕噜咕噜的声音这是不用说的，大大降低了品牌形象！
# ['异响', '声音'] :
# 中控异响一直是很多人反应的问题，这个问题在我驾驶期间并没有特别注意，自己车里摆了好多装饰也会发出声音，开车时候一般会开着音响也听不见了，只会有在特别安静的时候有时候能偶尔听见咯吱咯吱的几声，平时还是挺安静的。
# ['售价', '普通车'] :
# 不满意的地方还没有发现。我有个同学现在在奔驰，据他说C200L挺不值得，就是普通车套上了一个奔驰车壳，在配置上还是其他方面都不太值它得售价。反正都已经买了，反正自己喜欢最重要。
# ['后视镜', '折叠'] :
# 没有电动后视镜折叠。
# ['保养', '维修'] :
# ...

# %%
def loadDataset():
    corpus = ''
    #加载停用词表
    stop = [line.strip().decode('utf-8') for line in open('..\data\stop_words_2.txt','rb').readlines() ]
    with open('..\data\data_C_just_negative_review.csv', 'r', encoding='utf-8') as f:
        for line in f:
            segs = jieba.lcut(line.strip(), cut_all=True)   #, cut_all=True
            segs = pseg.cut(line)
            final = ''
            for seg, flag in segs:
                #去停用词
                if seg not in stop:
                   #去数词和去字符串
                   if flag !='m' and flag !='x':
                    #输出分词
                        final +=' '+ seg 
#             corpus.append(final)
            corpus += ' ' +final 
            
    return corpus
dataset = loadDataset()[1:]

# %%
tv=TfidfVectorizer(min_df=0.,max_df=1.,norm='l2',use_idf=True,smooth_idf=True)
tv_matrix=tv.fit_transform([dataset])
#print(tv_matrix)
tv_matrix=tv_matrix.toarray()
#print(tv_matrix)
vocab=tv.get_feature_names()
df_neg = pd.DataFrame(np.round(tv_matrix,2),columns=vocab).T.sort_values(by=[0],ascending=False)
df_neg.columns = ['tf-idf']
df_neg[0:20]
# Out:
#      tf-idf
# 空间     0.33
# 异响     0.29
# 后排     0.26
# 顿挫     0.24
# 奔驰     0.24
# 声音     0.21
# 发动机    0.18
# 问题     0.16
# 刹车     0.15
# 倒车     0.14
# 雷达     0.14
# 油耗     0.14
# 座椅     0.12
# 味道     0.12
# 起步     0.12
# 保养     0.10
# 导航     0.09
# 车门     0.08
# 启动     0.08
# 换挡     0.08

# %%
df_neg.to_csv('..\data\data_C_negative_keyword.csv')
